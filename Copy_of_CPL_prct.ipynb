# %% [markdown]
# <a href="https://colab.research.google.com/github/pehesara076/BankManagementSystem/blob/master/Copy_of_CPL_prct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [1,2,3,4,5,6,7,8]
squared = list(map(lambda x: x ** 2,numbers))
print("Squared: ", squared)
# Out:
# Squared:  [1, 4, 9, 16, 25, 36, 49, 64]
